# %%
from bluesky import RunEngine
RE = RunEngine({})

from bluesky.callbacks.best_effort import BestEffortCallback
bec = BestEffortCallback()

# Send all metadata/data captured to the BestEffortCallback.
RE.subscribe(bec)

from databroker import Broker
db = Broker.named('temp')

# Insert all metadata/data captured into db.
RE.subscribe(db.insert)

from ophyd.sim import motor1,motor2, noisy_det, det1

# %%
from bluesky.plans import scan

plan = scan([noisy_det,det1],motor1,-1,1,10)

RE(plan)
# Out:
# Transient Scan ID: 1     Time: 2022-10-24 10:48:44
# Persistent Unique Scan ID: '1bbc0f60-2301-4951-92b6-99329cdcca21'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+
# |   seq_num |       time |     motor1 |       det1 |  noisy_det |
# +-----------+------------+------------+------------+------------+
# |         1 | 10:48:45.0 |     -1.000 |      0.677 |      1.083 |
# |         2 | 10:48:45.1 |     -0.778 |      1.491 |      0.956 |
# |         3 | 10:48:45.3 |     -0.556 |      2.697 |      1.058 |
# |         4 | 10:48:45.4 |     -0.333 |      4.004 |      1.006 |
# |         5 | 10:48:45.5 |     -0.111 |      4.878 |      1.030 |
# |         6 | 10:48:45.6 |      0.111 |      4.878 |      0.994 |
# |         7 | 10:48:45.7 |      0.333 |      4.004 |      0.984 |
# |         8 | 10:48:45.8 |      0.556 |      2.697 |      0.924 |
# |         9 | 10:48:45.9 |      0.778 |      1.491 |      0.981 |
# ...

# %%
# !cd /home/jupyter-oaese/undulator_dev
import bpm
from id import UndulatorGap as ug
from id import Undulator as u, UndulatorElliptical as ue
from id import allIDs
# Out:
# Traceback (most recent call last):
#
#   File "/opt/tljh/user/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-18-0c9352caa1f3>", line 2, in <module>
#     import bpm
#
#   File "/home/jupyter-oaese/undulator_dev/bpm.py", line 52
#
#     ^
# SyntaxError: invalid syntax

# %%
# !pwd
# Out:
# /home/jupyter-oaese/undulator_dev
